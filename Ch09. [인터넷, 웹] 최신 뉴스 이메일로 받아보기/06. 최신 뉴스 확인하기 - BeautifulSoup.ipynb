# %% [markdown]
# # BeautifulSoup
# - BeautifulSoup는 Selenium, Scrapy 등과 같이 대표적인 파이썬 웹 크롤링 라이브러리
# - HTML 정보로부터 원하는 데이터를 가져오기 쉽게, 비슷한 분류의 데이터별로 나누어 주는 (parsing) 기능 제공
# - 보통 html 정보를 가져오는 urllib.request.urlopen() 모듈과 함께 사용
# - find() 함수를 통해서 원하는 html 태그 추출

# %%
# BeautifulSoup 설치
from bs4 import BeautifulSoup

# %% [markdown]
# # 크롤링 웹 페이지 확인

# %%
url = 'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y'

# %% [markdown]
# # html 헤더 설정
# - html 헤더는 클라이언트와 서버거 통신할 때 함께 전달하는 부가 정보로 날짜, 인코딩 정보, 유저 정보 등 다양한 내용을 담고 있음
# - user-agent에는 운영체제, 소프트웨어 버전, 소프트웨어 유형 등 여러 내용이 포함되어 있음
# - 헤더 정보 일람 사이트
# - https://www.useragentstring.com/pages/useragentstring.php

# %% [markdown]
# # 헤더 추가

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"}

# %%
# 서버 응답 확인
import requests

response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %% [markdown]
# # 뉴스 정보 크롤링

# %%
# BeautifulSoup 객체 생성
beautifulSoup = BeautifulSoup(response.content, 'html.parser')
beautifulSoup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image">
# <meta content="다양한 기사 정보를 제공합니다." property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="다양한 기사 정보를 제공합니다." name="twitter:description"/>
# <title>연합뉴스
# 			 속보 홈 : 네이버 뉴스	</title>
# <link href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20240215_143856/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20240215_143856/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20240215_143856/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20240215_143856/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='sec';
# var _MAIN_NEWS_SECTION_ID='';
# var ccsrv='cc.naver.com';
# var g_ssc='news.press';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness=3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
# var gnb_item_hide_option=128;
#
# var gnb_timestamp = "Mon Feb 19 20:54:01 KST 2024";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20240215_143856/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/factcheck/main"><span class="tx">팩트체크</span> </a></li>
# <li><a class="nclicks(lnb.algo)" href="https://media.naver.com/algorithm"><span class="tx">알고리즘 안내</span> </a></li>
# <li><a class="nclicks(lnb.correct)" href="/main/ombudsman/revisionArticleList.naver?mid=omb"><span class="tx">정정보도 모음</span> </a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>02</strong>.<strong>19</strong><span class="day">(월)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h"><a class="nclicks(lmn_fla.home)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=001">속보</a></h2>
# <ul class="nav">
# <li><a class="snb_s nclicks(lmn_fla.pol)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=100">정치 </a></li>
# <li><a class="snb_s2 nclicks(lmn_fla.eco)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=101">경제 </a></li>
# <li><a class="snb_s3 nclicks(lmn_fla.soc)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=102">사회 </a></li>
# <li><a class="snb_s4 nclicks(lmn_fla.lif)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=103">생활/문화 </a></li>
# <li><a class="snb_s5 nclicks(lmn_fla.wor)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=104">세계 </a></li>
# <li><a class="snb_s6 nclicks(lmn_fla.sci)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=105">IT/과학 </a></li>
# <li><a class="snb_s9 nclicks(lmn_fla.col)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=110">오피니언 </a></li>
# <li class="on"><a class="snb_s10 nclicks(lmn_fla.yon)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y">연합뉴스 속보 <span class="blind">선택됨</span></a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_fla.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_fla.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_header newsflash_header">
# <h3>연합뉴스 속보</h3>
# <p class="ytn_info"><span class="bar">|</span> 이 페이지는  연합뉴스가 직접 편집합니다.</p>
# </div>
# <div class="list_body newsflash_body">
# <div class="ytn_top">
# <dl class="type04">
# <dt class="photo"><a href="https://n.news.naver.com/mnews/article/001/0014514296?sid=000000"><img alt="전공의 수천명 집단사직…정부는 의협 집행부 '면허정지' 맞불" height="90" src="https://imgnews.pstatic.net/image/origin/001/2024/02/19/14514296.jpg?type=nf175_110" width="132"/>
# <span class="trans_border"></span></a></dt>
# <dt><a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014514296?rc=N&amp;ntype=RANKING">전공의 수천명 집단사직…정부는 의협 집행부 '면허정지' 맞불</a></dt>
# <dd>세브란스·대전성모 등 무더기 사직…20일엔 근무중단 예고경찰청장 "구속수사 검토"…경실련 "'담합' 공정위 고발"수술 절반 줄어들며 환...
#             <div class="emphasis_info _rcount" data-comment="{gno:'news001,0014514296',nclicks:'fls.cmt'}"><span class="writing">연합뉴스</span><span class="date">2024.02.19</span></div>
# <ul>
# <li class="_rcount" data-comment="{gno:'news001,0014514134',nclicks:'fls.cmt'}">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/001/0014514134?rc=N&amp;ntype=RANKING">암수술 무기한 연기되고, 응급실은 '마비'…'의료대란' 시작됐다</a><span class="writing">연합뉴스</span><span class="date">2024.02.19</span>
# </li>
# <li class="_rcount" data-comment="{gno:'news001,0014513378',nclicks:'fls.cmt'}">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/001/0014513378?rc=N&amp;ntype=RANKING">전공의 집단사직 시작됐다…'수술대란'에 정부 "진료유지명령"</a><span class="writing">연합뉴스</span><span class="date">2024.02.19</span>
# </li>
# <li class="_rcount" data-comment="{gno:'news001,0014513068',nclicks:'fls.cmt'}">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/001/0014513068?rc=N&amp;ntype=RANKING">경찰청장 "의사 집단행동 강한 수사, 주동자는 구속수사 검토"</a><span class="writing">연합뉴스</span><span class="date">2024.02.19</span>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# <ul class="type02">
# <li class="_rcount" data-comment="{gno:'news001,0014514292',nclicks:'fls.cmt'}">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014514292?rc=N&amp;ntype=RANKING"><strong>尹 "의료계, 국민 못 이겨…지난 정부처럼 지나가지 않겠다"</strong></a>
# <span class="writing">연합뉴스</span>
# <span class="date">2024.02.19. 오후 8:19</span>
# </li>
# <li class="_rcount" data-comment="{gno:'news001,0014514289',nclicks:'fls.cmt'}">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014514289?rc=N&amp;ntype=RANKING"><strong>與 최재형·윤희숙 등 단수공천…김기현·이철규는 경선</strong></a>
# <span class="writing">연합뉴스</span>
# <span class="date">2024.02.19. 오후 8:13</span>
# </li>
# <li class="_rcount" data-comment="{gno:'news001,0014514252',nclicks:'fls.cmt'}">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014514252?rc=N&amp;ntype=RANKING"><strong>김영주 국회부의장, 민주당 탈당 선언…"하위 20% 통보 모멸감"</strong></a>
# <span class="writing">연합뉴스</span>
# <span class="date">2024.02.19. 오후 6:56</span>
# </li>
# <li class="_rcount" data-comment="{gno:'news001,0014514029',nclicks:'fls.cmt'}">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014514029?rc=N&amp;ntype=RANKING"><strong>한동훈-조국, '석사장교' 논쟁…"운동권 맞나" "어불성설"</strong></a>
# <span class="writing">연합뉴스</span>
# <span class="date">2024.02.19. 오후 4:44</span>
# </li>
# <li class="_rcount" data-comment="{gno:'news001,0014514158',nclicks:'fls.cmt'}">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014514158?rc=N&amp;ntype=RANKING"><strong>이준석계-이낙연계 '총선지휘권' 충돌…개혁신당 내홍 확전기로</strong></a>
# <span class="writing">연합뉴스</span>
# <span class="date">2024.02.19. 오후 5:24</span>
# </li>
# <li class="_rcount" data-comment="{gno:'news001,0014514243',nclicks:'fls.cmt'}">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014514243?rc=N&amp;ntype=RANKING"><strong>총선 50일 앞둔 여야, '실거주 의무 3년 유예' 합의</strong></a>
# <span class="writing">연합뉴스</span>
# <span class="date">2024.02.19. 오후 6:44</span>
# </li>
# <li class="_rcount" data-comment="{gno:'news001,0014514285',nclicks:'fls.cmt'}">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014514285?rc=N&amp;ntype=RANKING"><strong>기상악화·광주공항 폭발물 소동에 제주공항 141편 결항</strong></a>
# <span class="writing">연합뉴스</span>
# <span class="date">2024.02.19. 오후 7:56</span>
# </li>
# <li class="_rcount" data-comment="{gno:'news001,0014514172',nclicks:'fls.cmt'}">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014514172?rc=N&amp;ntype=RANKING"><strong>류현진, 12년 만의 한화 컴백 임박…모그룹도 "복귀 논의 중"</strong></a>
# <span class="writing">연합뉴스</span>
# <span class="date">2024.02.19. 오후 5:31</span>
# </li>
# <li class="_rcount" data-comment="{gno:'news001,0014514171',nclicks:'fls.cmt'}">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014514171?rc=N&amp;ntype=RANKING"><strong>화요일 동해안·강원산지 대설…최대 10㎝ 이상 적설</strong></a>
# <span class="writing">연합뉴스</span>
# <span class="date">2024.02.19. 오후 5:30</span>
# </li>
# </ul>
# </div>
# <div class="paging paging_ytn">
# <strong>1</strong>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240219&amp;page=2">2</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240219&amp;page=3">3</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240219&amp;page=4">4</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240219&amp;page=5">5</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240219&amp;page=6">6</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240219&amp;page=7">7</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240219&amp;page=8">8</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240219&amp;page=9">9</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240219&amp;page=10">10</a>
# </div>
# <h4 class="blind">연합뉴스 이전날짜 더보기 링크모음</h4>
# <div class="pagenavi_day pagenavi_day_ytn">
# <span class="viewday">2월19일(월)</span><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240218">2월18일(일)</a><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240217">2월17일(토)</a><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240216">2월16일(금)</a><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LPOD&amp;sid2=140&amp;sid1=001&amp;mid=sec&amp;oid=001&amp;isYeonhapFlash=Y&amp;date=20240215">2월15일(목)</a></div>
# <ul class="ytn_bottom">
# <ul class="ytn_bottom">
# <li>
# <dl class="type05">
# <dt>
#      화제의 사진/영상
#    </dt>
# <dd class="type_photo">
# <ul>
# <li> <a href="https://www.yna.co.kr/view/AKR20240219112900008?input=1195z"> <img alt="" height="110" src="https://imgnews.pstatic.net/image/origin/001/2024/02/19/14514030.jpg?type=nf175_110" width="175"> [마켓톺] 일본, 대만 다음은 한국?…박스 탈출 노리는 코스…<span class="trans_border"></span> </img></a> </li>
# <li> <a href="https://www.yna.co.kr/view/AKR20240219116300063?input=1195z"> <img alt="" height="110" src="https://imgnews.pstatic.net/image/origin/001/2024/02/19/14514023.jpg?type=nf175_110" width="175"/> KAIST 총학 "두려움·분노…학생들 권리 짓밟히면 행동할 …<span class="trans_border"></span> </a> </li>
# <li> <a href="https://www.yna.co.kr/view/AKR20240219074700104?input=1195z"> <img alt="" height="110" src="https://imgnews.pstatic.net/image/origin/001/2024/02/19/14513099.jpg?type=nf175_110" width="175"/> '세계 최대 1일 선거' 치른 인니서 투표관리원 23명 과로로 …<span class="trans_border"></span> </a> </li>
# </ul>
# </dd>
# </dl> </li>
# </ul>
# <ul class="ytn_bottom">
# <li>
# <dl class="type05">
# <dt>
# </dt>
# <dd class="type_photo">
# <ul>
# </ul>
# </dd>
# </dl> </li>
# </ul>
# <ul class="ytn_bottom">
# <li>
# <dl class="type05">
# <dt>
#      디지털뉴스
#    </dt>
# <dd class="type_photo">
# <ul>
# <li> <a href="https://www.yna.co.kr/view/AKR20240216107500797?input=1195z"> <img alt="" height="110" src="https://imgnews.pstatic.net/image/origin/001/2024/02/19/14512130.jpg?type=nf175_110" width="175"/> [인턴이간다] 면접용 정장 무료! 직접 빌려봤습니다<span class="trans_border"></span> </a> </li>
# <li> <a href="https://www.yna.co.kr/view/AKR20240216133900797?input=1195z"> <img alt="" height="110" src="https://imgnews.pstatic.net/image/upload/item/2024/02/18/174751261_AKR20240216133900797_02_i_P4.jpg" width="175"/> [톺뉴스] 줄서서 '금동대향로' 산다?…박물관 굿즈 품절 대…<span class="trans_border"></span> </a> </li>
# <li> <a href="https://www.yna.co.kr/view/AKR20240215150900797?input=1195z"> <img alt="" height="110" src="https://imgnews.pstatic.net/image/upload/item/2024/02/16/125936625_AKR20240215150900797_01_i_P4.jpg" width="175"/> [인턴이간다] 명동 거리가게서 카드도 받는다고?<span class="trans_border"></span> </a> </li>
# </ul>
# </dd>
# </dl> </li>
# </ul>
# </ul>
# <div class="yonhap_banner">
# <h3> <a href="https://www.yna.co.kr/" target="_blank"><img alt="연합뉴스" height="60" src="https://imgnews.pstatic.net/image/upload/item/2016/10/20/161931909_nban01.png" width="145"/></a> <a href="http://www.yonhapnewstv.co.kr" target="_blank"><img alt="연합뉴스 TV" height="60" src="https://imgnews.pstatic.net/image/upload/item/2016/10/20/162012054_nban02.png" width="145"/></a> <a href="https://news.einfomax.co.kr/" target="_blank"><img alt="연합인포맥스" height="60" src="https://imgnews.pstatic.net/image/upload/item/2016/10/20/162028043_nban03.png" width="145"/></a> <a href="http://www.worktv.or.kr" target="_blank"><img alt="한국직업방송" height="60" src="https://imgnews.pstatic.net/image/upload/item/2016/10/20/162057294_nban04.png" width="145"/></a> </h3>
# </div>
# <script type="text/javascript">
#   window.onload = function() {
#     var selected_item = jindo.$('_');
#     if (selected_item != null) {
#       selected_item.className = "highlight";
#       news.section.ScrollingManager.scroll('');
#     }
#   }
#   news.section.MainIssueCollectManager.init({
#     mediaOneDomain : 'https://n.news.naver.com'
#   });
#   news.util.CommentListCountManager.view();
# </script>
# </div>
# </td>
# <td class="aside">
# <div class="aside">
# <div class="section _officeTopRanking1087479">
# <h4>언론사별 가장 많이 본 뉴스</h4>
# <button class="section_info_icon nclicks('rig.renws2i') _rankingInfoButton" type="button">안내</button>
# <div class="section_info_layer _rankingInfoLayer" style="display: none">각 언론사의 가장 많이 본 기사 1건을 제공합니다. <button class="section_info_layer_close _rankingInfoCloseButton nclicks('rig.renws2x')" type="button"><span>닫기</span></button></div>
# <p class="section_sub_txt">오후 7시~오후 8시까지 집계한 결과입니다.</p>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList0" style="display: block">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/020/0003548733?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/020/2024/02/19/3548733.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article
jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000037298?ntype=RANKING&amp;sid=001">이제 정말 푸바오와 '헤어질 결심'.. 마지막 작별 날짜  …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000002483?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/665/2024/02/19/2483.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000002483?ntype=RANKING&amp;sid=001">"비트코인의 봄은 봄일까" 크립토 스프링 허와 실 [See …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16"/></span>더스쿠프</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/353/0000047253?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/353/2024/02/19/47253.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/353/0000047253?ntype=RANKING&amp;sid=001">(주)다니엘컴퍼니, 17곡물 미미뻥 2023 한국브랜드 소 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=353"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/353/2018/09/20/logo_353_56_20180920154420.png" width="16"/></span>중앙SUNDAY</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000020375?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2024/02/19/20375.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000020375?ntype=RANKING&amp;sid=001">옷장 속 셔츠 하나 툭 걸쳤더니 ‘긱 시크’가 되었다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087479");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/020/0003548788?sid=165" title="김종민 “이준석, 김종인에 공천권 맡기려 통합 파기 기획”">김종민 “이준석, 김종인에 공천권 맡기려 통합 파기 기획”</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001999712?sid=100" title='개혁신당 "이준석에 캠페인·정책 등 선거 지휘 위임"'>개혁신당 "이준석에 캠페인·정책 등 선거 지휘 위임"</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004301768?sid=165" title="與 지역구 재배치 돌입…'컷오프' 반발 본격화">與 지역구 재배치 돌입…'컷오프' 반발 본격화</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/366/0000971058?sid=104" title="축구 국대 탁구 사건, 해외서도 난리... “유망주가 메시랑 싸운 격”">축구 국대 탁구 사건, 해외서도 난리... “유망주가 메시랑 싸운 격”</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001999829?sid=104" title='"일본어·풍습 모르면…" 日 호텔서 韓 관광객 숙박 거부 논란'>"일본어·풍습 모르면…" 日 호텔서 韓 관광객 숙박 거부 논란</a>
# </li>
# </ul>
# <ul class="list_txt">
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0012379963?sid=101" title="금융당국, 이르면 내달 첫 새마을금고 검사…건전성 점검">금융당국, 이르면 내달 첫 새마을금고 검사…건전성 점검</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/082/0001256267?sid=101" title="삼성전자 이재용 회장 ‘내우외환’ 어쩌나">삼성전자 이재용 회장 ‘내우외환’ 어쩌나</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004301522?sid=101" title="16년만에 30년 국채선물 상장, WGBI 편입 탄력받나">16년만에 30년 국채선물 상장, WGBI 편입 탄력받나</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004301689?sid=102" title="정보통신기획평가원 제4대 홍진배 원장 취임">정보통신기획평가원 제4대 홍진배 원장 취임</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/018/0005676047?sid=105" title="네이버클라우드, ‘한국수력원자력 특화 생성형 AI’ 협력">네이버클라우드, ‘한국수력원자력 특화 생성형 AI’ 협력</a>
# </li>
# </ul>
# <ul class="list_txt">
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/005/0001674954?sid=102" title="“폴더 지우고 병원 나와라”… 전공의 필독 행동지침 시끌">“폴더 지우고 병원 나와라”… 전공의 필독 행동지침 시끌</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/366/0000971400?sid=105" title="정부, 의협 집행부 2명에 ‘면허정지 행정처분’ 사전통지">정부, 의협 집행부 2명에 ‘면허정지 행정처분’ 사전통지</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0014514240?sid=102" title="광주 공군기지 폭발물 의심에 주민 대피 소동…'화들짝'">광주 공군기지 폭발물 의심에 주민 대피 소동…'화들짝'</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0012379523?sid=103" title="제작사-방송사 간 관행 개선, 제작비 등 인식 차이">제작사-방송사 간 관행 개선, 제작비 등 인식 차이</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0014514171?sid=103" title="화요일 동해안·강원산지 대설…최대 10㎝ 이상 적설">화요일 동해안·강원산지 대설…최대 10㎝ 이상 적설</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://factcheck.snu.ac.kr/" target="_blank"> <img alt="온라인 허위정보, 팩트체크 어떻게 확인할까요" src="https://imgnews.pstatic.net/image/upload/item/2020/02/05/175955946_%2540banner_300X80_pc.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/algorithm"> <img alt="알고리즘 안내" src="https://imgnews.pstatic.net/image/upload/item/2023/07/06/183901500_banner_AI.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2023/06/23/195329402_banner_24hours.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이정규</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
# 페이지 제목 크롤링
print(beautifulSoup.title)
print(beautifulSoup.title.string)
print(beautifulSoup.title.text)
# Out:
# <title>연합뉴스
# 			 속보 홈 : 네이버 뉴스	</title>
# 연합뉴스
# 			 속보 홈 : 네이버 뉴스
# 연합뉴스
# 			 속보 홈 : 네이버 뉴스

# %%
# 페이지 상단 텍스트 크롤링
print(beautifulSoup.find("dl", attrs={"class": "type04"}).get_text())
# Out:
# 전공의 수천명 집단사직…정부는 의협 집행부 '면허정지' 맞불
# 세브란스·대전성모 등 무더기 사직…20일엔 근무중단 예고경찰청장 "구속수사 검토"…경실련 "'담합' 공정위 고발"수술 절반 줄어들며 환...
#             연합뉴스2024.02.19
#
#
# 암수술 무기한 연기되고, 응급실은 '마비'…'의료대란' 시작됐다연합뉴스2024.02.19
#
#
# 전공의 집단사직 시작됐다…'수술대란'에 정부 "진료유지명령"연합뉴스2024.02.19
#
#
# 경찰청장 "의사 집단행동 강한 수사, 주동자는 구속수사 검토"연합뉴스2024.02.19

# %%
# 페이지 하단 텍스트 크롤링
print(beautifulSoup.find("ul", attrs={"class": "type02"}).get_text())
# Out:
# 尹 "의료계, 국민 못 이겨…지난 정부처럼 지나가지 않겠다"
# 연합뉴스
# 2024.02.19. 오후 8:19
#
#
# 與 최재형·윤희숙 등 단수공천…김기현·이철규는 경선
# 연합뉴스
# 2024.02.19. 오후 8:13
#
#
# 김영주 국회부의장, 민주당 탈당 선언…"하위 20% 통보 모멸감"
# 연합뉴스
# 2024.02.19. 오후 6:56
#
#
# 한동훈-조국, '석사장교' 논쟁…"운동권 맞나" "어불성설"
# 연합뉴스
# 2024.02.19. 오후 4:44
#
#
# 이준석계-이낙연계 '총선지휘권' 충돌…개혁신당 내홍 확전기로
# 연합뉴스
# 2024.02.19. 오후 5:24
#
#
# 총선 50일 앞둔 여야, '실거주 의무 3년 유예' 합의
# 연합뉴스
# 2024.02.19. 오후 6:44
#
#
# 기상악화·광주공항 폭발물 소동에 제주공항 141편 결항
# 연합뉴스
# 2024.02.19. 오후 7:56
#
#
# 류현진, 12년 만의 한화 컴백 임박…모그룹도 "복귀 논의 중"
# 연합뉴스
# 2024.02.19. 오후 5:31
#
#
# 화요일 동해안·강원산지 대설…최대 10㎝ 이상 적설
# 연합뉴스
# 2024.02.19. 오후 5:30
